# %%
import numpy as np
import os
import pickle
import copy 
import json
import warnings
warnings.filterwarnings("ignore")
from load_img import Load_from_Folder, Load_Images
from evaluate import Time, MSE, PSNR
from LANCZOS import *
from GIC import GIC

def downsample(X, r):
    a, b =  LANCZOS.split(X, r)   
    return a
def run1():
    n_img=-1
    par_old1 = {
        "n_hop": 6, 
        "win": {"hop1": [512, 256, 128, 64, 32, 16, 8], 
                "hop2": [256, 128, 64, 32, 16, 8], 
                "hop3": [128, 64, 32, 16, 8, 4], 
                "hop4": [64, 32, 16,8, 4], 
                "hop5": [32, 16, 8, 4], 
                "hop6": [16, 8, 4]}, 
        "MSE_TH": {"hop1": [-1, 70, 70, 70, 70, 70, 70], 
                "hop2": [-1, 70, 70, 70, 70, 70], 
                "hop3": [-1, 70, 70, 70, 70, 40], 
                "hop4": [-1, 70, 70, 70, 70], 
                "hop5": [-1, 70, 70, 70], 
                "hop6": [-1, 70, 70]}, 
        'n_clusters': {'hop1': [64, 128, 512, 512, 512, 512, 64], 
                    'hop2': [64, 128, 512, 512, 512, 128], 
                    'hop3': [64, 128, 512, 512, 512, 512], 
                    'hop4': [64, 128, 512, 512, 512], 
                    'hop5': [64, 32, 64, 128], 
                    'hop6': [64, 32, 64]}, 
        "shape": {"hop6": [[n_img, 1, 1, 1], [n_img, 2, 2, 1], [n_img, 4, 4, 1]], 
                  "hop5": [[n_img, 1, 1, 1], [n_img, 2, 2, 1], [n_img, 4, 4, 1], [n_img, 8, 8, 1]], 
                  "hop4": [[n_img, 1, 1, 1], [n_img, 2, 2, 1], [n_img, 4, 4, 1], [n_img, 8, 8, 1], [n_img, 16, 16, 1]], 
                  "hop3": [[n_img, 1, 1, 1], [n_img, 2, 2, 1], [n_img, 4, 4, 1], [n_img, 8, 8, 1], [n_img, 16, 16, 1], [n_img, 32, 32, 1]], 
                  "hop2": [[n_img, 1, 1, 1], [n_img, 2, 2, 1], [n_img, 4, 4, 1], [n_img, 8, 8, 1], [n_img, 16, 16, 1], [n_img, 32, 32, 1]], 
                  "hop1": [[n_img, 1, 1, 1], [n_img, 2, 2, 1], [n_img, 4, 4, 1], [n_img, 8, 8, 1], [n_img, 16, 16, 1], [n_img, 32, 32, 1], [n_img, 64, 64, 1]]},
        "n_components": {"hop1":[150, 150, 150, 150, 30, 20, None],
                         "hop2":[150, 150, 150, 30, 20, None],
                         "hop3":[150, 150, 30, 20, 12, None],
                         "hop4":[150, 30, 20, 12, None],
                         "hop5":[30, 20, 12, None],
                         "hop6":[20, 12, None]},

    "gpu": {"hop1": [False, False, False, False, False, False, False, False, False], 
            "hop2": [False, False, False, False, False, False, False, False], 
            "hop3": [False, False, False, False, False, False, False], 
            "hop4": [False, False, False, False, False, False], 
            "hop5": [False, False, False, False, False], 
            "hop6": [False, False, False, False]}}
    
    
    print('--------------------start---------------------')
    print(par_old1)
    with open('dataset.json', 'r') as json_file:
        DataSet = json.load(json_file)
    Y = Load_from_Folder(folder=DataSet['CLIC_train_1024x1024_more'], color='RGB', ct=-1)+\
        Load_from_Folder(folder=DataSet['Holopix50k_trainR_1024x1024'], color='RGB', ct=2000)
    Y = np.array(Y).astype('float32')
    Y = downsample(Y, 2)
    print(Y.shape)
    gic = GIC(par_old1)
    gic.fit(Y)
    return gic

# %%
gic = run1()
# Out:
# --------------------start---------------------
# ...

# %%
from color_space import *
x = cv2.imread('lena512color.tiff')
x = BGR2RGB(x)
x = x.reshape(1, 512, 512, -1).astype('float32')
Y = x#downsample(x, 2)
stream, dc, save = gic.encode(Y)
iY = gic.decode(stream, dc)
print('MSE=%5.3f, PSNR=%3.5f'%(MSE(Y, iY), PSNR(Y, iY)))
# Out:
#    <RunTime> foreward:  0.0 s
# hop6
#    <RunTime> backward:  0.0 s
# hop5
#    <RunTime> backward:  0.0 s
# hop4
#    <RunTime> backward:  0.0 s
# hop3
#    <RunTime> backward:  0.0 s
# hop2
#    <RunTime> backward:  0.1 s
# hop1
#
# Testing MSE: 112.58926262661306
# Hop-1
#    save tree:0.00339127
#   Level-0 Huffman 0.00000381 bpp
#   Level-1 Huffman 0.00001526 bpp
#   Level-2 Huffman 0.00015640 bpp
#   Level-3 Huffman 0.00094986 bpp
#   Level-4 Huffman 0.00479507 bpp
#   Level-5 Huffman 0.01803589 bpp
#   Level-6 Huffman 0.03934097 bpp
# Hop-2
#    save tree:0.00091934
#   Level-0 Huffman 0.00000381 bpp
#   Level-1 Huffman 0.00001526 bpp
#   Level-2 Huffman 0.00018692 bpp
#   Level-3 Huffman 0.00107193 bpp
#   Level-4 Huffman 0.00471878 bpp
#   Level-5 Huffman 0.01300430 bpp
# Hop-3
#    save tree:0.00120926
#   Level-0 Huffman 0.00000381 bpp
#   Level-1 Huffman 0.00001526 bpp
#   Level-2 Huffman 0.00023651 bpp
#   Level-3 Huffman 0.00184250 bpp
# ...

# %%
with open('dataset.json', 'r') as json_file:
    DataSet = json.load(json_file)
Y = Load_from_Folder(folder=DataSet['CLIC_test_1024x1024_more'], color='RGB', ct=-1)
Y = np.array(Y).astype('float32')
Y = downsample(Y, 2)
stream, dc, save = gic.encode(Y)
iY = gic.decode(stream, dc)
print('MSE=%5.3f, PSNR=%3.5f'%(MSE(Y, iY), PSNR(Y, iY)))
print('--------------------end---------------------\n\n\n')
# Out:
#    <RunTime> foreward:  9.9 s
# hop6
#    <RunTime> backward:  0.1 s
# hop5
#    <RunTime> backward:  0.4 s
# hop4
#    <RunTime> backward:  1.3 s
# hop3
#    <RunTime> backward:  5.6 s
# hop2
#    <RunTime> backward: 10.1 s
# hop1
#
# Testing MSE: 219.94490013195235
# Hop-1
#    save tree:0.00306017
#   Level-0 Huffman 0.00000381 bpp
#   Level-1 Huffman 0.00001471 bpp
#   Level-2 Huffman 0.00014283 bpp
#   Level-3 Huffman 0.00076511 bpp
#   Level-4 Huffman 0.00424377 bpp
#   Level-5 Huffman 0.01793103 bpp
#   Level-6 Huffman 0.04397380 bpp
# Hop-2
#    save tree:0.00085708
#   Level-0 Huffman 0.00000381 bpp
#   Level-1 Huffman 0.00002139 bpp
#   Level-2 Huffman 0.00014947 bpp
#   Level-3 Huffman 0.00105669 bpp
#   Level-4 Huffman 0.00469310 bpp
#   Level-5 Huffman 0.01399627 bpp
# Hop-3
#    save tree:0.00093600
#   Level-0 Huffman 0.00000381 bpp
#   Level-1 Huffman 0.00002832 bpp
#   Level-2 Huffman 0.00025466 bpp
#   Level-3 Huffman 0.00143988 bpp
# ...

# %%
with open('/mnt/yifan/gic_512-0919.pkl', 'wb') as f:
    pickle.dump(gic, f, 4)

# %%
refit = {"hop1": [(False, 0),(False, 0), (False, 0), (False, 0), (False, 0), (False, 0), (False, 8)], 
       "hop2": [(False, 0), (False, 0), (False, 0), (False, 0), (False, 0), (False, 0), (False, 0)], 
       "hop3": [(False, 0), (False, 0), (False, 0), (False, 0), (False, 0), (False, 0)], 
       "hop4": [(False, 0), (False, 0), (False, 0), (False, 0), (False, 0)], 
       "hop5": [(False, 0), (False, 0), (False, 0), (False, 0)], 
       "hop6": [(False, 0), (False, 0), (False, 0)]}

with open('dataset.json', 'r') as json_file:
    DataSet = json.load(json_file)
Y_train = Load_from_Folder(folder=DataSet['CLIC_train_1024x1024_more'], color='RGB', ct=-1)+\
        Load_from_Folder(folder=DataSet['Holopix50k_trainR_1024x1024'], color='RGB', ct=2000)
a = [8, 16,32, 64, 128]
tmp = {}
tmp1 = {}
for i in a:
    print(i,'----------------------------------')
    
    Y = np.array(copy.deepcopy(Y_train)).astype('float32')
    Y = downsample(Y, 2)
    refit['hop1'][-1] = (True, i)
    gic.refit(Y, refit)
    with open('/mnt/yifan/gic_512_'+str(i)+'.pkl', 'wb') as f:
        pickle.dump(gic, f, 4)
    Y = None
    from color_space import *
    x = cv2.imread('lena512color.tiff')
    x = BGR2RGB(x)
    
    Y = x.reshape(1, 512, 512, -1).astype('float32')
    stream, dc, save = gic.encode(Y)
    iY = gic.decode(stream, dc)
    print('MSE=%5.3f, PSNR=%3.5f'%(MSE(Y, iY), PSNR(Y, iY)))
    #'''
    tmp[i] = iY
    Y = None
    print('----------------------------------------------------------------------')
    Y = Load_from_Folder(folder=DataSet['CLIC_test_1024x1024_more'], color='YUV', ct=-1)
    Y = np.array(Y).astype('float32')
    Y = downsample(Y, 2)
    stream, dc, save = gic.encode(Y)
    iY = gic.decode(stream, dc)
    tmp1[i] = iY
    print('MSE=%5.3f, PSNR=%3.5f'%(MSE(Y, iY), PSNR(Y, iY)))
    print('--------------------end---------------------\n\n\n')
    #'''
    
with open('/mnt/yifan/lena_512.pkl','wb') as f:
    pickle.dump(tmp,f)
    
with open('/mnt/yifan/clic_test_512.pkl','wb') as f:
    pickle.dump(tmp1,f,4)
# Out:
# 8 ----------------------------------
#    <RunTime> foreward: 192.6 s
# hop6
# MBVQ channel 3
#    <RunTime> rebackward:  3.3 s
# hop5
# MBVQ channel 3
#    <RunTime> rebackward:  9.2 s
# hop4
# MBVQ channel 3
#    <RunTime> rebackward: 33.8 s
# hop3
# MBVQ channel 3
#    <RunTime> rebackward: 148.3 s
# hop2
# MBVQ channel 3
#    <RunTime> rebackward: 251.3 s
# hop1
# MBVQ channel 3
#    MBVQ refit 6 8
#
# Training MSE: 141.72346521804627
#    <RunTime> refit: 1717.1 s
#    <RunTime> foreward: 150.4 s
# hop6
#    <RunTime> backward:  1.8 s
# hop5
#    <RunTime> backward:  4.9 s
# hop4
#    <RunTime> backward: 18.1 s
# hop3
#    <RunTime> backward: 83.8 s
# hop2
#    <RunTime> backward: 205.9 s
# hop1
#
# Testing MSE: 141.72346521804627
#    <RunTime> refit: 3226.4 s
#    <RunTime> foreward:  0.1 s
# hop6
#    <RunTime> backward:  0.0 s
# hop5
#    <RunTime> backward:  0.0 s
# hop4
#    <RunTime> backward:  0.0 s
# hop3
#    <RunTime> backward:  0.1 s
# hop2
# ...

# %%
with open('/mnt/yifan/clic_test_512.pkl','wb') as f:
    pickle.dump(tmp1,f,4)
